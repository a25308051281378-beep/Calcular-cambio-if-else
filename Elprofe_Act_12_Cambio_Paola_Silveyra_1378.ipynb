# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051281378-beep/Calcular-cambio-if-else/blob/main/Elprofe_Act_12_Cambio_Paola_Silveyra_1378.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Paola Silveyra  NL = 50 Fecha 26/03/26
# ### Calculando el cambio usando if else
# ### mirar diagrama de flujo
# <img src="https://raw.githubusercontent.com/a25308051281378-beep/Calcular-cambio-if-else/refs/heads/main/cambio3.jpg" width="400" height="400" alt="Texto descriptivo">
#
# ## Variables
# 1. CP -->  Costo del producto
# 2. CD -->  Cantidad de dinero
# 3. Cambio
#
# ## Formulas
# $Cambio = CD - CP$
#
# ## Diagrama de flujo LucidChart
# <img src="https://raw.githubusercontent.com/a25308051281378-beep/Calcular-cambio-if-else/refs/heads/main/DF%20if%20else%20cambio2.png" width="600" height="500" alt="Texto descriptivo">

# %%
# Calculando el cambio usando if else
# datos de entrada CD , CP
# mostrar Cambio si es falso
# si es verdadero mostrar  No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
    Cambio = CD - CP
    print("El cambio es: ", Cambio)
print("Fin del programa")
print("Programa realizado por Paola Silveyra NL = 50")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 400
# No alcanza
# Fin del programa
# Programa realizado por Paola Silveyra NL = 50

# %%
# para cuando es falso (No)
# Calculando el cambio usando if else
# datos de entrada CD , CP
# mostrar Cambio si es falso
# si es verdadero mostrar  No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
    Cambio = CD - CP
    print("El cambio es: ", Cambio)
print("Fin del programa")
print("Programa realizado por Paola Silveyra NL = 50")
# Out:
# Ingrese el costo del producto: 250
# Ingrese la cantidad de dinero: 300
# El cambio es:  50.0
# Fin del programa
# Programa realizado por Paola Silveyra NL = 50

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo
# <img src="https://raw.githubusercontent.com/a25308051281378-beep/Calcular-cambio-if-else/refs/heads/main/TLDraw%20codigo%20DF.png" width="800" height="500" alt="Texto descriptivo">
